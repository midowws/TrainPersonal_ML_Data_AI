# %%
import pandas as pd
import joblib
from sklearn.Randomforest import RandomForestClassifier

data_siap_prediksi = [[sl, sw, pl, pw]]

sl = float(input("Masukkan panjang sepal: "))
sw = float(input("Masukkan lebar sepal: "))
pl = float(input("Masukkan panjang petal: "))
pw = float(input("Masukkan lebar petal: "))

model_load.predict(data_siap_prediksi)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 3
#       1 import pandas as pd
#       2 import joblib
# ----> 3 from sklearn.Randomforest import RandomForestClassifier
#       5 data_siap_prediksi = [[sl, sw, pl, pw]]
#       7 sl = float(input("Masukkan panjang sepal: "))
#
# ModuleNotFoundError: No module named 'sklearn.Randomforest'
